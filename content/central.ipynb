# %% [markdown]
# # <font color=red>  <p style="text-align: center;">CENTRAL TELEFÓNICA <p>

# %% [markdown]
# ## <font color=red>  La central debe cumplir los siguientes requerimientos.<br>
# <font color=black>
#   <input type="checkbox" name="vehicle" value="Bike"> Capacidad de 400 abonados.<br>
#   <input type="checkbox" name="second" value="Segundo"> Debe tener aleatoriamente:
# - 20% abonados fuera de servicio.
# - 50% abonados ocupados.
# - 30% abonados fuera de Servicio.
#
# <input type="checkbox" name="three" value="Tercero"> Utilizar la señalización necesaria para todolos los casos.<br>
#   <input type="checkbox" name="fourth" value="Cuarto"> Sistema de Numeración para la señal telefonica.<br>
#   <input type="checkbox" name="three" value="tercero"> Generar los tonos de marcación por numero marcado siguiendo siguiendo un recomendación ITU-T o estandar.<br>
#   <input type="checkbox" name="three" value="tercero">  Simular la llamada y almacenar el tiempo de la llamada y acumularlo con otras del usuario.<br>
#   <input type="checkbox" name="three" value="tercero">  Generar historial de llamadas y calcular el costo de la llamada en imprimirlo en pantalla.
# </form>
# -

# %% [markdown]
# ### <font color=red> Clase Abonados:
#
# <font color=black> <p style="text-align: center;"> __Esta clase me va a representar los abonados en el servicio.__
#
#  <img src="https://rawgit.com/sebastiankmilo/conmutacionusco/master/imagenes/ClaseAbonado.png" ></a>
#
# La clase posee los atributos:
# - **nombre** que es tipo _String_
# - **telefono** que es tipo _Entero( int )_
# - **tiempo** que es tipo _flotante_
# - **estado** que es tipo int
#
# y posee los metodos:
# - **SaveTime(acción)**: Es la encargada de obtener cuando tiempo se va a demorar la llamada, tiene como parametro la _llamada_ y devuelve el tiempo que se demoro.
# - **addTime(tiempo)**: Es la encargada de agregar la duración de las llamadas que realice el abonado, su parametro es el _tiempo de duración de la ultima llamada que realizo el usuario_.

# %%
from datetime import datetime


class Abonado(object):


    def __init__(self, nombre, telefono, estado):
        self.nombre = nombre
        self.telefono = telefono
        self.tiempo=0
        self.lastcalltime=0
        self.estado=estado
        pass

    def SaveTime(self, accion,):
        to = datetime.now()
        accion(destino,origen)
        tf = datetime.now()
        time = tf-to
        time = time.seconds
        self.lastcalltime = time
        return time
    def AddTime(self, tiempo):
        self.tiempo=self.tiempo+tiempo
        pass
    def __str__(self):
        return self.nombre+' : '+str(self.telefono)
    pass
    

pass

# %% [markdown]
# ### <font color=red> Clase Tonos:
#     esta Clase sera la encargada de manejar las diferenteres   señalizaciones del sistema
#
# <img src="https://rawgit.com/sebastiankmilo/conmutacionusco/master/imagenes/ClaseTono.png" ></a>
#
# La clase posee los siguientes atributos:
# - __tonos__: Es un diccionario donde se van a almacenar los tonos y audios que se vanllan a usar para la señalización
#
# Posee los siguientes metodos:
# - __Timbrar(Abonado origen)__: Es el q se encarga de generar el sonido de cuando se esta timbrando.
# - __Contestar(Abonado destino)__: Se encarga de reproducir la señalización correspondiente a cuando el abonado esta disponible,ocupado o fuera de servicio.
# - __Tecla(numero)__: Se encarga de reproducir el tono que le correspone a cada tono cuando esta siendo marcado.

# %%
import pygame.mixer
from time import sleep


class Tonos(object):

    def __init__(self):
        self.tonos = {10: "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\T0.wav",
                      1: "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\T1.wav",
                      2: "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\T2.wav",
                      3: "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\T3.wav",
                      4: "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\T4.wav",
                      5: "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\T5.wav",
                      6: "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\T6.wav",
                      7: "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\T7.wav",
                      8: "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\T8.wav",
                      9: "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\T9.wav",
                      'disponible': "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\disponible.m4a",
                      'ocupado': "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\Ocupado.wav",
                      'fuera de servicio': "C:\Users\Usuario\Desktop\Universidad\9 semestre\Conmutacionpython\sonidos\FueraS.wav"
                      }
        pass

    def load(self, tono):
        pygame.mixer.init()
        pygame.mixer.music.load(open(self.tonos[tono], "rb"))
        pygame.mixer.music.play()
        while pygame.mixer.music.get_busy():
            sleep(1)
        pass
    pass
pass

# %% [markdown]
# ### <font color=red>Clase Central Telefonica

# %%
import sys,os
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
import Abonado,Tonos
from datetime import datetime
class CentralTelefonica(object):
    tonos=Tonos.Tonos()
    def __init__(self, abonados,indicativo):
        self.abonados=abonados
        self.Indicativo=indicativo
        self.historial=[]
        pass
    def llamar(self,usuario,destino):
        self.abonados[usuario].estado=0
        n=self.abonados[destino].estado
        if self.abonados[destino].estado==-1:
            tonos.load('fuera de servicio')
            self.abonados[destino].estado=n
            pass
        elif self.abonados[destino].estado==0:
            tonos.load('ocupado')
            self.abonados[destino].estado=n
            pass
        elif self.abonados[destino].estado==1:
            tonos.load('disponible')
            self.abonados[destino].estado=n
            pass
        self.historial.append(datetime.now())
        pass
    def cobrar(usuario):
        tarifaPorSegundo=2
        saldo=self.abonados[usuario].tiempo*tarifaPorSegundo
        pass
    
    pass

# %% [markdown]
# ## <font color=red>Desarrollo De la Central Telefonica con las especificaciones solicitadas

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import sys
import os
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
    pass
import ipywidgets as widgets
from IPython.display import display
from random import shuffle
from Tonos import Tonos
from Abonado import Abonado
from Central import CentralTelefonica
from random import randrange

t = Tonos()
x = range(400)
ListaAbonados = []
shuffle(x)
for y in xrange(400):
    terminado = str(x[y])
    if x[y] < 10:
        telefono = "860000"
        pass
    elif x[y] < 100:
        telefono = "86000"
        pass
    else:
        telefono = "8600"
        pass
    if y < 79:
        estado = -1
        pass
    elif y < 279:
        estado = 0
        pass
    else:
        estado = 1
        pass
    telefono = int(telefono+terminado)
    persona = 'sujeto de prueba #'+terminado
    abno = Abonado(persona, telefono, estado)
    ListaAbonados.append(abno)
    pass
d={ListaAbonados[0].telefono: ListaAbonados[0]}
for x in xrange(1,400):
    d[ListaAbonados[x].telefono]=ListaAbonados[x]
    pass
Central1 = CentralTelefonica(d, '57')
global usuario
usuario=8600200
items_layout = widgets.Layout(width='100%',
                              height='100%',
                              justify_content='flex-end')
style = {'value_align': 'center'}
pantallita = widgets.Text(value='0000000', disabled=True,
                          layout=items_layout, style=style)
pantallita2 = widgets.HTML(value='<p style="text-align: center;">8600317<p>')
words = ['1', '2', '3', '4', '5', '6', '7',
         '8', '9', 'clear', '0', 'llamar', 'fact', 'histo']
items = [widgets.Button(description=w) for w in words]
c1 = widgets.VBox(children=[items[0], items[3], items[6], items[9]])
c2 = widgets.VBox(children=[items[1], items[4], items[7], items[10]])
c3 = widgets.VBox(children=[items[2], items[5], items[8], items[11]])
f4 = widgets.HBox(children=[items[12], items[13]])
b = [c1, c2, c3]
box_layout = widgets.Layout(display='flex',
                            flex_flow='column',
                            align_items='center',
                            border='solid',
                            width='50%')
box2_layout = widgets.Layout(display='flex',
                            flex_flow='column',
                            align_items='center',
                            border='solid',
                            width='100%',
                            height='100%')
box = widgets.Box(children=b)
f4 = widgets.VBox(children=[pantallita2, box, f4], layout=box_layout)
usuariot=str(usuario)
titulo=widgets.HTML(value='<p style="text-align: center;">Factura para '+usuariot+'<p>',layout=items_layout)
precio=str(Central1.cobrar(usuario))
contenido=widgets.HTML(value='<p style="text-align: center;">'+'Saldo:'+precio+'<p>',layout=items_layout)
fact=widgets.VBox(children=[titulo,contenido],layout=box2_layout)
title=widgets.HTML(value='<p style="text-align: center;">'+'<b>HISTORIAl<b><p>',layout=items_layout)
cont=widgets.HTML(value='<p style="text-align: center;">',layout=items_layout)
hist=widgets.VBox(children=[title, cont],layout=box2_layout)
box4=widgets.VBox(children=[fact, hist],layout=box_layout)
total=widgets.HBox(children=[f4,box4])
contador = 0


def remplazo(n):
    texto = pantallita2.value
    texto1 = texto[texto.find('>')+1:texto.find('<', 3, len(texto)-1)]
    pos = len(texto1)-1
    tecla = n
    textol = list(texto1)
    textol.append(tecla)
    pos = len(textol)
    if pos < 7:
        texto2 = []
        texto2 = textol
        pass
    else:
        texto2 = textol[1:pos]
        pass
    telefono = "".join(texto2)
    texto = '<p style="text-align: center;">'+telefono+'<p>'
    pantallita2.value = texto
    pass

def bo0(b):
    t.load(10)
    remplazo('0')
    global contador
    contador = contador+1
    pass

def bo1(b):
    t.load(1)
    remplazo('1')
    global contador
    contador = contador+1
    pass

def bo2(b):
    t.load(2)
    remplazo('2')
    global contador
    contador = contador+1
    pass

def bo3(b):
    t.load(3)
    remplazo('3')
    global contador
    contador = contador+1
    pass

def bo4(b):
    t.load(4)
    remplazo('4')
    global contador
    contador = contador+1
    pass

def bo5(b):
    t.load(5)
    remplazo('5')
    global contador
    contador = contador+1
    pass

def bo6(b):
    t.load(6)
    remplazo('6')
    global contador
    contador = contador+1
    pass

def bo7(b):
    t.load(7)
    remplazo('7')
    global contador
    contador = contador+1
    pass

def bo8(b):
    t.load(8)
    remplazo('8')
    global contador
    contador = contador+1
    pass

def bo9(b):
    t.load(9)
    remplazo('9')
    global contador
    contador = contador+1
    pass

def clear(b):
    global contador
    contador = 0
    telefono = '0000000'
    texto = '<p style="text-align: center;">'+telefono+'<p>'
    pantallita2.value = texto
    pass

def llamar(b):
    texto = pantallita2.value
    destinot = texto[texto.find('>')+1:texto.find('<', 3, len(texto)-1)]
    destino = int(destinot)
    Central1.llamar(usuario,destino)
    hist(destinot)
    pass


def fact(b):
    precio=str(Central1.cobrar(usuario))
    contenido.value='<p style="text-align: center;">'+'Saldo:'+precio+'<p>'
    print 'Me ejecute'
    pass


def hist(destino):
    x=len(Central1.historial)-1    
    llamada =destino+':'+str(Central1.historial[x].day)+'/'+str(Central1.historial[x].month)+'/'+str(Central1.historial[x].year)+' a las '+str(Central1.historial[x].hour)+':'+str(Central1.historial[x].minute)
    tiempo=str(Central1.abonados[usuario].lastcalltime)
    llamada=llamada+' tiempo:'.encode(encoding='UTF-8',errors='strict')+tiempo
    cont.value=cont.value+llamada+'<br>'
        

metodos = {0: bo0, 1: bo1, 2: bo2, 3: bo3, 4: bo4,
           5: bo5, 6: bo6, 7: bo7, 8: bo8, 9: bo9,
           10: clear, 12: llamar, 13: fact, 14: hist}
for n in xrange(14):
    if n == 10:
        items[10].on_click(metodos.get((0), ""))
        pass
    else:
        items[n].on_click(metodos.get((n+1), ""))
    pass
total
#col1 = widgets.VBox([items[0], items[3]], items[6])
#col2 = widgets.VBox([items[1], items[4]], items[7])
#col3 = widgets.VBox([items[2], items[5]], items[8])
#widgets.HBox([col1, col2, col3])
#8600267

# %%
x=0
llamada =str(Central1.historial[x].day)+'/'+str(Central1.historial[x].month)+'/'+str(Central1.historial[x].year)+' a las '+str(Central1.historial[x].hour)+':'+str(Central1.historial[x].minute)
print (llamada)
cont.value=cont.value+llamada+'<br>'
# Out:
# 13/3/2018 a las 6:21

# %%
x=0
llamada ='8602517'+':'+str(Central1.historial[x].day)+'/'+str(Central1.historial[x].month)+'/'+str(Central1.historial[x].year)+' a las '+str(Central1.historial[x].hour)+':'+str(Central1.historial[x].minute)
tiempo=str(Central1.abonados[usuario].lastcalltime)
llamada=llamada+' duración:'+tiempo
llamada
# Out:
# '8602517:13/3/2018 a las 6:36 duraci\xc3\xb3n:0'

# %%
d[8600200].tiempo

# %%
for x in xrange(0,400):
    print str(ListaAbonados[x].telefono) +':'+str(ListaAbonados[x].estado) 
    pass
# Out:
# 8600385:-1
# 8600254:-1
# 8600309:-1
# 8600345:-1
# 8600374:-1
# 8600030:-1
# 8600010:-1
# 8600298:-1
# 8600126:-1
# 8600136:-1
# 8600209:-1
# 8600170:-1
# 8600256:-1
# 8600225:-1
# 8600232:-1
# 8600321:-1
# 8600306:-1
# 8600351:-1
# 8600005:-1
# 8600021:-1
# 8600253:-1
# 8600188:-1
# 8600276:-1
# 8600357:-1
# 8600090:-1
# 8600278:-1
# 8600395:-1
# 8600370:-1
# 8600139:-1
# 8600073:-1
# 8600369:-1
# 8600103:-1
# 8600100:-1
# 8600241:-1
# 8600113:-1
# 8600207:-1
# 8600171:-1
# 8600219:-1
# 8600032:-1
# 8600131:-1
# 8600061:-1
# 8600117:-1
# 8600205:-1
# 8600327:-1
# 8600240:-1
# 8600092:-1
# 8600221:-1
# 8600104:-1
# 8600210:-1
# 8600086:-1
# 8600190:-1
# 8600202:-1
# 8600098:-1
# 8600166:-1
# 8600299:-1
# 8600014:-1
# 8600361:-1
# 8600001:-1
# 8600242:-1
# 8600346:-1
# 8600036:-1
# 8600216:-1
# 8600135:-1
# 8600208:-1
# 8600148:-1
# 8600102:-1
# 8600194:-1
# 8600284:-1
# 8600137:-1
# 8600181:-1
# 8600245:-1
# 8600236:-1
# 8600366:-1
# 8600338:-1
# 8600191:-1
# 8600287:-1
# ...

# %%
print ListaAbonados[x].telefono) +':'+ListaAbonados[x].estado
